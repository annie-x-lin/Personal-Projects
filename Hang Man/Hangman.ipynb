# %%
#hang man fruit edition
import random
list1=["apple","banana","peach","pineapple","pear","orange","cherry","mango","grape","berry","strawberry","grapefruit","watermelon","limon","kiwi","coconut","lychee","fig"]


def function1(x):
    print("Welcome to Hangman!")
    print("Theme:Fruits")
    listnew=[]
    listother=[]
    for d in list(x):
        listnew.append(d)
    for f in range(len(x)):
        listother.append("_")
    print("Number of letters: "+str(len(listnew)))
    print (listother)
    print("")
    count=0
    count1=0
    for z in range(600):
        if count1==len(listnew):
                print("you got it!")
                print("")
                print("\\O/")
                print(" | ")
                print("/ \\")
                break
        guess=input("Input a letter or a word: ")
        if guess in listnew:
            listother[listnew.index(guess)]=guess
            listnew[listnew.index(guess)]=""
            count1+=1
            if guess in listnew:
                listother[listnew.index(guess)]=guess
                listnew[listnew.index(guess)]=""
                count1+=1
                if guess in listnew:
                    listother[listnew.index(guess)]=guess
                    listnew[listnew.index(guess)]=""
                    count1+=1
            print(listother)   
            print("")
        elif guess == x:
            print ("You got it!")
            print("")
            print("\\O/")
            print(" | ")
            print("/ \\")
            break
        else: 
            count+=1
            if count <6:
                print(listother)
                print("Try again!")
                print("")
                if count==1:
                    print("O")
                    print("")
                elif count ==2:
                    print("O")
                    print("|")
                    print("")
                elif count ==3:
                    print(" O ")
                    print("/|")
                    print("")
                elif count ==4:
                    print(" O ")
                    print("/|\\")
                    print("")
                elif count ==5:
                    print(" O ")
                    print("/|\\")
                    print("/")
                    print("")
            else:
                print(" O ")
                print("/|\\")
                print("/ \\")
                print("Hangman!")
                print("")
                print("The word was: "+guess)
                break
    
         
function1(random.choice(list1))
# Out:
# Welcome to Hangman!
# Theme:Fruits
# Number of letters: 10
# ['_', '_', '_', '_', '_', '_', '_', '_', '_', '_']
#
# Input a letter or a word: draganf
# ['_', '_', '_', '_', '_', '_', '_', '_', '_', '_']
# Try again!
#
# O
#
# Input a letter or a word:
# ['_', '_', '_', '_', '_', '_', '_', '_', '_', '_']
# Try again!
#
# O
# |
#
# Input a letter or a word: d
# ['_', '_', '_', '_', '_', '_', '_', '_', '_', '_']
# Try again!
#
#  O
# /|
#
# Input a letter or a word: e
# ['_', '_', '_', '_', 'e', '_', '_', '_', '_', '_']
#
# Input a letter or a word: g
# ['g', '_', '_', '_', 'e', '_', '_', '_', '_', '_']
#
# Input a letter or a word: ra
# ['g', '_', '_', '_', 'e', '_', '_', '_', '_', '_']
# Try again!
#
#  O
# /|\
#
# Input a letter or a word:
# ['', '_', '_', '_', 'e', '_', '_', '_', '_', '_']
#
# Input a letter or a word: grapefruit
# You got it!
#
# \O/
#  |
# / \
